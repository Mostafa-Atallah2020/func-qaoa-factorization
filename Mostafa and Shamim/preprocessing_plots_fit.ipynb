# %%
from plt_sets import *

# %%
num_of_chunks = 15 
data_fit = {}
maxpows = list(range(20,81,20))
maxpows.append(93)
for i,maxpow in enumerate(maxpows):
    biprimes, qubits = get_data_qubits_biprimes(maxpow)
    make_plots(biprimes,qubits,maxpow)
    xdata = np.asarray(list(map(math.log2,biprimes)))
    data_fit[i] = get_fit(xdata,qubits,num_of_chunks)
# Out:
# (19.545385069397906, 7203907.444139061)
# (4.288756102755206, 22.780348214929916)
# (16.150797241347302, 8239595732720.871)
# (4.013533476385509, 42.905710693446835)
# (5.05956301275093, 1.5244872108829118e+19)
# (2.3390127867849104, 63.72495785030614)
# (2.4744038779872435, 5.088791243624023e+25)
# (1.3070809995924262, 85.3955253813483)
# (4.053243527257135, 4.8234714372870704e+29)
# (2.0190768580917595, 98.60598657510249)
