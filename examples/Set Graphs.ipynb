# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append(f"./../")
from src.sets_graph import SetsGraph

# %%
sets = [{1, 2, 3}, {4, 3, 6}, {3, 8, 4}, {9, 1}]
graph = SetsGraph(sets)
disjoint_sets = graph.disjoint_sets
graph.draw()

# %%
disjoint_sets
# Out:
# [{3, 4, 6}, {1, 9}]
